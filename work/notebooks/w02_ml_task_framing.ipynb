# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/faja27/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# I call this a classification problem first, then a ranking problem after. The model needs to guess yes/no for each page (is it declining or not), but what actually gets used is the ranked list from that probability, not the yes/no itself. So it's classification that feeds into a ranking output

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# Right now I'm predicting is_declining_label, which just means trend_direction == "down". I know this isn't a real future outcome, it's more of a snapshot label based on the current window. It's a proxy, not the actual thing I care about. Later on I'd rather build something like: use the last 90 days of features to predict decline in the next 30 days, that would actually be forward-looking instead of just describing what already happened

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# I going with Precision@50. Reason is simple, a reviewer isn't going to check thousands of pages, realistically maybe 50 at a time. So precision at that cutoff tells me something useful, while a metric like overall accuracy wouldn't really match how this gets used in practice

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# One row here is one content page. content_id is the id, the rest are the signals i looking at plus the label at the end

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/faja27/flyrank-ml-internship"
REPO_DIR = "flyrank-ml-internship"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)

import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
df["is_declining_label"] = df["trend_direction"].str.lower().eq("down").astype(int)

unit = df[["content_id", "impressions_90d", "days_since_last_update",
           "avg_position", "ctr", "trend_direction", "is_declining_label"]]
print(unit.shape)
unit.head()
# Out:
# (30000, 7)
#              content_id  impressions_90d  days_since_last_update  \
# 0  content_304f48230142             3803                      20
# 1  content_a1fb4e703a9e            15320                      25
# 2  content_9aa793d4d895            12581                      20
# 3  content_331d6c4de07b            11751                      22
# 4  content_d99b7a2d90ca            19140                      14
#
#    avg_position   ctr trend_direction  is_declining_label
# 0          10.6  0.76            down                   1
# 1          20.3  0.05            down                   1
# 2          36.5  0.09            down                   1
# 3           6.2  0.49          stable                   0
# 4          44.0  0.13            down                   1

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# I already saw this play out in Week 1. My own hand rule (stale + visible) only hit 0.240 on Precision@50, but the random forest from the same pipeline got 0.740, almost triple. A rule I write by hand can only really combine 2-3 conditions before it gets messy, but there's clearly more going on, visibility, freshness, position, CTR all interact with each other in ways I can't just write as an if/else without it turning into a huge nested mess.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
